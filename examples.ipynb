# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import heatconduction as hc

# %%
khi = 9e-7  # thermal diffusivity
V0, V1 = 15, 5

x = np.linspace( 0, .5, 40 )  # m

T = hc.caractime( khi, .5 )  # transition time 

t = np.linspace( .5*tc, 1.5*tc, 16 )

# %%
v = hc.semiinfiniteconstant( x, t, V0, V1, T, khi )
plt.plot( x, np.transpose(v) ); plt.xlabel('x (m)') ;
plt.ylabel('temperature (°C)') ;

# %%
khi = 9e-7 # thermal diffusivity

tc = hc.caractime( khi, .5 )

A = 20  # amplitude

T = tc/4

x = np.linspace( 0, .5, 40 )
t = np.linspace( 0, tc, 16 )

# %%
v = hc.semiinfiniteharmonic( x, t, A, T, khi )
plt.plot( x, np.transpose(v) ); plt.xlabel('x (m)') ;
plt.ylabel('temperature (°C)') ;

# %%
## todo: Fourier serie
